# %%
# import serial
from time import sleep
import numpy as np
import cv2
from IPython.display import clear_output
# %matplotlib inline
from matplotlib import pyplot as plt

from utils import ones_state, vis, state_ones

# %%
BOARD_X, BOARD_Y = 400, 650
REST_X, REST_Y = 400, 500
BOARD_SIZE = 64
SPACE_SIZE = 100

# %%
class TwoAxis():
    def __init__(self):
        loc = "/dev/cu.usbmodem1411"
        self.ser = serial.Serial(loc, 115200)
        if self.ser is None:
            print("error, no serial")
            print("Don't forget to change the serial location for your system. Currently set to: {}".format(loc))
        
        print('waiting for response')
        #self.wait() # wait until ready
        sleep(2)
        self.ser.flush()
        print('connected')

    def wait(self):
        while True:
            if self.ser.readline():
                return
            
    def pen_down(self):
        self.ser.write(("00000,").encode('utf-8'))
    
    def pen_up(self):
        self.ser.write(("10000,").encode('utf-8'))

    def move(self, x_speed, y_speed):
        x_speed = int(np.floor((x_speed + 1.0)/2.0 * 99.0))
        y_speed = int(np.floor((y_speed + 1.0)/2.0 * 99.0))
        
        x_speed = "%02d"%x_speed
        y_speed = "%02d"%y_speed
        message = "2"+x_speed[0]+x_speed[1]+y_speed[0]+y_speed[1]+","
        #print(message)
        self.ser.write((message).encode('utf-8'))

# serial
ta = TwoAxis()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/serial/serialposix.py in open(self)
#     264         try:
# --> 265             self.fd = os.open(self.portstr, os.O_RDWR | os.O_NOCTTY | os.O_NONBLOCK)
#     266         except OSError as msg:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dev/cu.usbmodem1411'
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-3-0d5056b3b8f9> in <module>()
#      35
#      36 # serial
# ---> 37 ta = TwoAxis()
#
# <ipython-input-3-0d5056b3b8f9> in __init__(self)
#       2     def __init__(self):
#       3         loc = "/dev/cu.usbmodem1411"
# ----> 4         self.ser = serial.Serial(loc, 115200)
#       5         if self.ser is None:
#       6             print("error, no serial")
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/serial/serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     238
#     239         if port is not None:
# --> 240             self.open()
#     241
#     242     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/serial/serialposix.py in open(self)
#     266         except OSError as msg:
#     267             self.fd = None
# --> 268             raise SerialException(msg.errno, "could not open port {}: {}".format(self._port, msg))
#     269         #~ fcntl.fcntl(self.fd, fcntl.F_SETFL, 0)  # set blocking
#     270
#
# SerialException: [Errno 2] could not open port /dev/cu.usbmodem1411: [Errno 2] No such file or directory: '/dev/cu.usbmodem1411'

# %%
# camera

cam = cv2.VideoCapture(1)

# %%
# pattern tracking for pen location

template = cv2.imread('pattern.png', 0)

def capture_img(cam, template=template):
    
    ret_val, img = cam.read()

    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    img = np.transpose(img)
    img = np.flipud(img)
    img[img>100] = 200
    
    w, h = template.shape[::-1]

    res = cv2.matchTemplate(img, template, cv2.TM_CCOEFF)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    img = cv2.circle(img.copy(), max_loc, 20, 255, 20)
    
    return img, max_loc

img, max_loc = capture_img(cam)
print(max_loc)
plt.imshow(img, cmap=plt.cm.gray)
#plt.imshow(template)
# Out:
# (402, 498)

# %%
# controlled movement

from math import atan2

def move_targeted(x, y):
    target = (x, y)
    close = False
    while not close:
        img, loc = capture_img(cam)
        #clear_output(wait=True)
        #plt.imshow(img, cmap=plt.cm.gray)
        #plt.show()
        
        dist = np.sqrt(np.square(x-loc[0]) + np.square(y-loc[1]))
        
        if dist < 2:
            close = True
            ta.move(0.0, 0.0)
            return
        
        angle = atan2(y-loc[1], x-loc[0])
        
        speed = 1
        if dist < 20:
            speed = .2

        diffx = np.cos(angle) * speed
        diffy = np.sin(angle) * speed
        
        
        #print(diffx)
        #print(diffy)
        #print('location')
        #print(loc)
        #print('target')
        #print(target)

        ta.move(diffx, diffy)

        #sleep(.1)
        #plt.imshow(img)
        #plt.show()
        
def line_targeted(x1, y1, x2, y2, divisions=1):
    ta.pen_up()
    move_targeted(x1, y1)
    ta.pen_down()
    
    if divisions == 1:
        move_targeted(x2, y2)
    else:
        for i in np.linspace(0, 1, divisions):
            if i == 0:
                continue
            ix, iy = (1-i) * x1 + i * x2, (1-i) * y1 + i * y2
            move_targeted(ix, iy)
        
    ta.pen_up()
        
#move_targeted(550, 900)

# %%
move_targeted(REST_X, REST_Y)

# %%
# draw game board
def draw_board(sx, sy):
    # vert
    ta.pen_up()
    line_targeted(sx+SPACE_SIZE,    sy, sx+SPACE_SIZE,     sy+3*SPACE_SIZE)
    line_targeted(sx+2*SPACE_SIZE,   sy+3*SPACE_SIZE, sx+2*SPACE_SIZE,  sy)

    # horiz
    line_targeted(sx+3*SPACE_SIZE,   sy+SPACE_SIZE, sx, sy+SPACE_SIZE)
    line_targeted(sx, sy+2*SPACE_SIZE, sx+3*SPACE_SIZE,   sy+2*SPACE_SIZE)

# %%
# draw an x

def draw_x(pc, pr):
    pad = SPACE_SIZE/6
    r, c = BOARD_X + SPACE_SIZE*pr, BOARD_Y + SPACE_SIZE*pc
    line_targeted(r+pad, c+pad, r+SPACE_SIZE-pad, c+SPACE_SIZE-pad, divisions=6)
    line_targeted(r+pad, c+SPACE_SIZE-pad, r+SPACE_SIZE-pad, c+pad, divisions=6)

# %%
from detector import Detector

# detection
d = Detector(BOARD_SIZE, BOARD_SIZE, "weights-00-0.28.hdf5")
# Out:
# model created with # params: 507858
# loading model weights from path: weights-00-0.28.hdf5
# loaded weights
# c:\Users\aabdo\miniconda3\envs\tic_tac_toe\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# get game state

def board_state():
    # OFF_X, OFF_Y = -16, 34
    OFF_X, OFF_Y = 0, 0
    SCALE = 1/2.5

    ret_val, img = cam.read()

    img = np.transpose(img, axes=[1,0,2])
    img = np.flipud(img)
    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (int(img.shape[1]*SCALE), int(img.shape[0]*SCALE)))
    sr, sc = 55, 55
    # sr, sc = int(BOARD_Y*SCALE), int(BOARD_X*SCALE)
    #cv2.rectangle(img, (sc+OFF_X, sr+OFF_Y), (sc+OFF_X+BOARD_SIZE, sr+OFF_Y+BOARD_SIZE), 255, 4)
    img_rows, img_cols = 64, 64
    # img = img[sr+OFF_Y: sr+OFF_Y+BOARD_SIZE, sc+OFF_X: sc+OFF_X+BOARD_SIZE]
    img = img[sr:sr+img_rows, sc:sc+img_cols]
    #img[img>200] = 255
    
    img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 101, 15)
    img = img.astype(np.float64)
    img = 255-img
    img = img.astype(np.float64)
    img /= 255
    
    plt.imshow(img, cmap=plt.cm.gray)
    
    state = np.round(d.predict(img))
    
    return state

state = board_state()

vis(ones_state(state))
# cam.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# X - X
# O X -
# O X O

# %%
# create tictac ai
import t3_ai
t3 = t3_ai.AI(weights_path="t3_weights-19-0.24.hdf5")
# Out:
# model created with # params: 353
# loading model weights from path: t3_weights-19-0.24.hdf5
# loaded weights

# %%
ta.pen_up()
move_targeted(REST_X, REST_Y)

# %%
draw_board(BOARD_X, BOARD_Y)

# %%
# Make move based on the state

def rc_from_int(a):
    r = int(np.floor(a/3.0))
    c = a%3
    return r,c

def make_move(state):
    state = ones_state(state)
    besta = t3.best_move(state)
    print(besta)
    if besta < 0:
        move_targeted(REST_X+10, REST_Y)
        return
    r, c = rc_from_int(besta)
    print(r,c)
    draw_x(r, c)

confidence = 0
prev_observed = None
    
while True:
    move_targeted(REST_X, REST_Y)
    
    state = board_state()
    clear_output(wait=True)
    vis(ones_state(state))
    
    if np.all(prev_observed == state):
        confidence += 1
    else:
        confidence = 0
        prev_observed = state.copy()
        
    if confidence < 20:
        continue
    else:
        confidence = 0
    
    num_xs = np.sum(state[0:9])
    num_os = np.sum(state[9:])
    
    clear_output(wait=True)
    if num_xs == 0 and num_os == 0:
        # first ai move condition
        make_move(state)
    elif num_xs == num_os:
        # human has made their move
        make_move(state)
# Out:
# X O O
# O X X
# X X O
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/serial/serialposix.py in write(self, data)
#     533             try:
# --> 534                 n = os.write(self.fd, d)
#     535                 if timeout.is_non_blocking:
#
# OSError: [Errno 6] Device not configured
#
# During handling of the above exception, another exception occurred:
#
# SerialException                           Traceback (most recent call last)
# <ipython-input-15-23222d8453f1> in <module>()
#      21
#      22 while True:
# ---> 23     move_targeted(REST_X, REST_Y)
#      24
#      25     state = board_state()
#
# <ipython-input-6-3c8069d4687d> in move_targeted(x, y)
#      16         if dist < 2:
#      17             close = True
# ---> 18             ta.move(0.0, 0.0)
#      19             return
#      20
#
# <ipython-input-3-0d5056b3b8f9> in move(self, x_speed, y_speed)
#      32         message = "2"+x_speed[0]+x_speed[1]+y_speed[0]+y_speed[1]+","
#      33         #print(message)
# ---> 34         self.ser.write((message).encode('utf-8'))
#      35
#      36 # serial
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/serial/serialposix.py in write(self, data)
#     563             except OSError as v:
#     564                 if v.errno != errno.EAGAIN:
# --> 565                     raise SerialException('write failed: {}'.format(v))
#     566                 # still calculate and check timeout
#     567                 if timeout.expired():
#
# SerialException: write failed: [Errno 6] Device not configured

# %%
# take a camera shot

from scipy.misc import imsave

ret_val, img = cam.read()

img = np.transpose(img, axes=[1,0,2])
img = np.flipud(img)

print(img.shape)

imsave('ss.png', img)

# %%
# check cam images

while True:
    img, loc = capture_img(cam)
    clear_output(wait=True)
    plt.imshow(img, cmap=plt.cm.gray)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-7bc68b0e9932> in <module>()
#       4     img, loc = capture_img(cam)
#       5     clear_output(wait=True)
# ----> 6     plt.imshow(img, cmap=plt.cm.gray)
#       7     plt.show()
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3139            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    3140            hold=None, data=None, **kwargs):
# -> 3141     ax = gca()
#    3142     # Deprecated: allow callers to override the hold state
#    3143     # by passing hold=True|False
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#     948     matplotlib.figure.Figure.gca : The figure's gca method.
#     949     """
# --> 950     return gcf().gca(**kwargs)
#     951
#     952 # More ways of creating axes:
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1367
#    1368         # no axes found, so create one which spans the figure
# -> 1369         return self.add_subplot(1, 1, 1, **kwargs)
#    1370
#    1371     def sca(self, a):
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1019                     self._axstack.remove(ax)
#    1020
# -> 1021             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1022
#    1023         self._axstack.add(key, a)
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     527
#     528         # this call may differ for non-sep axes, e.g., polar
# --> 529         self._init_axis()
#     530         if axisbg is not None and facecolor is not None:
#     531             raise TypeError('Both axisbg and facecolor are not None. '
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in _init_axis(self)
#     621         "move this out of __init__ because non-separable axes don't use it"
#     622         self.xaxis = maxis.XAxis(self)
# --> 623         self.spines['bottom'].register_axis(self.xaxis)
#     624         self.spines['top'].register_axis(self.xaxis)
#     625         self.yaxis = maxis.YAxis(self)
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/spines.py in register_axis(self, axis)
#     161         self.axis = axis
#     162         if self.axis is not None:
# --> 163             self.axis.cla()
#     164         self.stale = True
#     165
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
# --> 152         self.gridline = self._get_gridline()
#     153
#     154         self.label1 = self._get_text1()
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axis.py in _get_gridline(self)
#     446                           linewidth=rcParams['grid.linewidth'],
#     447                           alpha=rcParams['grid.alpha'],
# --> 448                           markersize=0)
#     449         l.set_transform(self.axes.get_xaxis_transform(which='grid'))
#     450         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         self._color = None
#     403         self.set_color(color)
# --> 404         self._marker = MarkerStyle()
#     405         self.set_marker(marker)
#     406
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     185         self._fillstyle = fillstyle
#     186         self.set_marker(marker)
# --> 187         self.set_fillstyle(fillstyle)
#     188
#     189     def __getstate__(self):
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/markers.py in set_fillstyle(self, fillstyle)
#     230         """
#     231         if fillstyle is None:
# --> 232             fillstyle = rcParams['markers.fillstyle']
#     233         if fillstyle not in self.fillstyles:
#     234             raise ValueError("Unrecognized fillstyle %s"
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py in __getitem__(self, key)
#     932 See rcParams.keys() for a list of valid parameters.' % (key,))
#     933
# --> 934     def __getitem__(self, key):
#     935         inverse_alt = None
#     936         if key in _deprecated_map:
#
# KeyboardInterrupt:

# %%
def circle(x, y):
    r = 10
    ta.pen_up()
    for i, t in enumerate(np.linspace(0, np.pi * 2.0, 8)):
        move_targeted(x + np.cos(t) * r, y + np.sin(t) * r)
        if i == 0:
            ta.pen_down()
    ta.pen_up()
        
circle(REST_X, REST_Y+100)
# Out:
# 24949

# %%
draw_x(0, 0)
draw_x(1, 0)
draw_x(2, 0)

draw_x(2, 1)
draw_x(1, 1)
draw_x(0, 1)

draw_x(0, 2)
draw_x(1, 2)
draw_x(2, 2)

move_targeted(REST_X, REST_Y)
